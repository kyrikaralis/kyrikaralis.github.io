# %%
#Import Dependencies
import pandas as pd

# %%
df = pd.read_csv('REINOLSFBads.csv')
df.head()
# Out:
#   Reporting Starts Reporting Ends          Ad Name     Ad Delivery  \
# 0       2018-05-01     2018-12-29    WFA_Charlotte  not_delivering
# 1       2018-05-01     2018-12-29      WFA_Medford  not_delivering
# 2       2018-05-01     2018-12-29  Q2_WFA_Columbus  not_delivering
# 3       2018-05-01     2018-12-29  WFA_Los Angeles  not_delivering
# 4       2018-05-01     2018-12-29          WFA_LAX  not_delivering
#
#                                      Ad Set Name  Ad Set Budget  \
# 0   WFA_Charlotte (50mi)_Registration Lookalikes          225.0
# 1     WFA_Medford (50mi)_Registration Lookalikes          200.0
# 2        Q2_Classes_Columbus(40mi)_registrations          200.0
# 3  WFA_Los Angeles (50+)_Registration Lookalikes         1000.0
# 4                WFA_LAX_Registration Lookalikes         1000.0
#
#   Ad Set Budget Type  Results  \
# 0           Lifetime      5.0
# 1           Lifetime      3.0
# 2           Lifetime      2.0
# 3           Lifetime     34.0
# ...

# %%
df.to_html('table.html')
